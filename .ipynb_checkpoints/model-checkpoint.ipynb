# %%
import pandas as pd 

df = pd.read_csv('data/lines.csv')
df.head()
# Out:
#    id                       line
# 0   0    Те кто не нашёл счастья
# 1   1     Тем кто и не искал его
# 2   2  Тевтон как среди ястреб я
# 3   3     Те кто не кискал и вот
# 4   4    Тэйп дом и о том госпел

# %%
df.line = df.line.astype(str).apply(lambda x: x.split())
df.head()
# Out:
#    id                             line
# 0   0    [Те, кто, не, нашёл, счастья]
# 1   1    [Тем, кто, и, не, искал, его]
# 2   2  [Тевтон, как, среди, ястреб, я]
# 3   3    [Те, кто, не, кискал, и, вот]
# 4   4   [Тэйп, дом, и, о, том, госпел]

# %%
x_train = [line[:-1] for line in df.line]
y_train = [line[1:] for line in df.line]
# Out:
# [['Те', 'кто', 'не', 'нашёл'], ['Тем', 'кто', 'и', 'не', 'искал'], ['Тевтон', 'как', 'среди', 'ястреб'], ['Те', 'кто', 'не', 'кискал', 'и'], ['Тэйп', 'дом', 'и', 'о', 'том'], ['Текстов', 'и', 'басней'], ['И', 'оков', 'бряцанье', 'во'], ['Иаков', 'одобрял'], ['Монархи', 'один', 'из', 'животной', 'стадии', 'эволюции', 'на'], ['Закончив', 'за', 'цикл', 'должны', 'были', 'начать', 'новую', 'историю', 'ужаса', 'на'], ['И', 'начать', 'здесь', 'человеческую'], ['Они', 'были', 'теми', 'имплантами', 'которые'], ['Должна', 'была', 'передать', 'Земле', 'для', 'дальнейшего'], ['Тогда', 'как', 'сказано', 'в', 'легенде'], ['Великие', 'владыки', 'дали'], ['Падали', 'звёзды'], ['Капали', 'слёзы'], ['Падали', 'звёзды'], ['Надо', 'ли', 'плакать', 'надо', 'ли', 'Ещё'], ['Падали', 'звёзды'], ['Капали', 'слёзы'], ['Падали', 'звёзды'], ['Надо', 'ли', 'плакать'], ['Дерьмо', 'кто', 'расстрел'], ['Где', 'токсик', 'клеймо'], ['На', 'трон'], ['Пляшет', 'танец'], ['Белые', 'зубы', 'в', 'темноту'], ['Свет'], ['Потом', 'на', 'амбразуру', 'как'], ['Спасибо', 'но', 'мы', 'не'], ['Падали', 'звёзды'], ['Капали', 'слёзы'], ['Падали', 'звёзды'], ['Надо', 'ли', 'плакать', 'надо', 'ли', 'Ещё'], ['Друзья', 'я', 'хочу', 'сказать', 'я', 'зашкварился', 'Я', 'зашкварился', 'но', 'не', 'потому', 'что', 'батлюсь', 'с', 'ним', 'щяс', 'я', 'объясню', 'вам', 'всё'], ['Привет', 'Гене', 'Rickey', 'F', 'Витале', 'Alphavit', 'Айо', 'Пу', 'Раа'], ['Я', 'попросил', 'биты', 'помедленней', '140'], ['Ведь', 'я', 'не', 'умею', 'моргать', 'тут', 'быстрее', 'чем'], ['А', 'ты', 'словно', 'Eminem', 'белый', 'негр', 'на'], ['Букер', 'ДФред', 'это', 'значит', 'на', 'английском'], ['Ёбаный', 'ты', 'бомж', 'в', 'прыщах', 'всё'], ['Твое', 'новое', 'flow', 'перечитает', 'Эзоп'], ['Ты', 'хоть', 'нажрись'], ['Ты', 'не', 'молодой', 'Чинаски', 'ты', 'Артур'], ['Кто', 'виновенто', 'что', 'батл', 'это', 'просто'], ['Кто', 'виновен', 'то', 'что', 'каждый', 'батлрепер'], ['Я', 'отвечу', 'Это', 'я', 'я', 'во', 'всём', 'виноват', 'здесь', 'ведь', 'я', 'батлю', 'только', 'с', 'корешами', 'Джубили'], ['Они', 'говорят', 'я'], ['Но', 'жал', 'ли', 'вам', 'руку'], ['Мы', 'знаем'], ['Versus', 'Battle', 'это', 'топовая', 'лига', 'в'], ['Ресторатор', 'катит', 'на', 'Бимере', 'вы', 'на'], ['Obladaet'], ['Loqiemean', 'и', 'Обе', 'Ван', 'батлят', 'под', 'одеялом', 'ведь', 'их', 'там', 'батлит'], ['Весь', 'батлрэп', 'трусливые', 'бляди', 'Fresh', 'Blood', 'полный'], ['Вы', 'всё', 'проебали', 'стыдно', 'за'], ['Как', 'было', 'стыдно', 'и', 'в'], ['И', 'где', 'же', 'ваши'], ['Гарри', 'Топор'], ['И', 'если', 'это', 'цирк', 'вот', 'вам', 'топовый'], ['Устройте', 'баттл', 'карликов', 'Джарахов', 'и', 'Вова'], ['И', 'только', 'сам', 'Оксимирон', 'сам', 'Оксимирон', 'с', 'небес', 'спустился', 'чтобы', 'защитить', 'свой', 'батловый'], ['Респуктуля'], ['Ты', 'не', 'забатлишь', 'Галата', 'но', 'забатлишь', 'на', 'телеке', 'Харламова', 'и'], ['Что', 'до'], ['Букер', 'круче', 'всех'], ['Но', 'я', 'ебу', 'Букера', 'как', 'старух', 'у'], ['Как', 'Старуха', 'ебала', 'Букера', 'год'], ['Молодая', 'кровь', 'идёт', 'нахуй', 'ведь', 'я', 'тут'], [], ['Замай', 'здесь', 'настоящий', 'не'], ['Репосты', 'правильные', 'лайки'], ['Бля', 'мне', 'так', 'это'], ['Бро', 'Ёу', 'Ёу'], ['Замай', 'старый'], ['Эй', 'дедуля', 'погоди', 'ты', 'залетел', 'не', 'в', 'ту'], ['Вышел', 'батлить', 'на', 'биты', 'и', 'сразу', 'прячешься', 'под'], ['В', 'двух', 'словах', 'ты'], ['В', 'трёх', 'словах', 'Замай', 'ты'], ['Хочешь', 'баттл', 'но', 'потёк', 'от', 'Хована', 'как', 'будто'], ['Пишешь', 'в'], ['Пишешь'], ['Хочешь'], ['Слышишь'], ['Старику', 'надо', 'медаль', 'дать', 'за', 'то', 'что', 'он', 'смог'], ['Прихожу', 'ебать', 'дедов', 'в', 'публичном', 'доме'], ['Когда', 'батлишься', 'боишься', 'проебать', 'вставную'], ['А', 'лицо', 'будто', 'хочет', 'чтобы', 'дали'], ['Пенсионер'], ['Попей', 'чаёк', 'с'], ['Ты', 'хрипишь', 'как', 'мотоцикл', 'что', 'заправили'], ['Достаю', 'клинок', 'из', 'сала', 'как', 'король', 'Артур'], ['Видел', 'ты', 'дрочил', 'на', ' ...

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.line)
x_train = tokenizer.texts_to_sequences(x_train)
y_train = tokenizer.texts_to_sequences(y_train)
print(x_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18520/1499415484.py in <module>
#       4 tokenizer = Tokenizer()
#       5 tokenizer.fit_on_texts(df.line)
# ----> 6 x_train = tokenizer.texts_to_sequences(x_train)
#       7 y_train = tokenizer.texts_to_sequences(y_train)
#       8 print(x_train)
#
# c:\users\valer\appdata\local\programs\python\python39\lib\site-packages\keras_preprocessing\text.py in texts_to_sequences(self, texts)
#     279             A list of sequences.
#     280         """
# --> 281         return list(self.texts_to_sequences_generator(texts))
#     282
#     283     def texts_to_sequences_generator(self, texts):
#
# c:\users\valer\appdata\local\programs\python\python39\lib\site-packages\keras_preprocessing\text.py in texts_to_sequences_generator(self, texts)
#     307                 seq = text
#     308             else:
# --> 309                 seq = text_to_word_sequence(text,
#     310                                             self.filters,
#     311                                             self.lower,
#
# c:\users\valer\appdata\local\programs\python\python39\lib\site-packages\keras_preprocessing\text.py in text_to_word_sequence(text, filters, lower, split)
#      41     """
#      42     if lower:
# ---> 43         text = text.lower()
#      44
#      45     if sys.version_info < (3,):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'lower'

# %%
lengths = []

for sequence in x_train:
    lengths.append(len(sequence))
    
lengths = pd.Series(lengths)
lengths.describe()
# Out:
# count    20056.0
# mean        20.0
# std          0.0
# min         20.0
# 25%         20.0
# 50%         20.0
# 75%         20.0
# max         20.0
# dtype: float64

# %%
# максимальное колическтво слов
maxlen=20

x_train = pad_sequences(x_train, maxlen=maxlen, padding='post', truncating='post')
y_train = pad_sequences(y_train, maxlen=maxlen, padding='post', truncating='post')
print(x_train)
# Out:
# [[  210    35     0 ...     0     0     0]
#  [  241    35     0 ...     0     0     0]
#  [10464     6     0 ...     0     0     0]
#  ...
#  [    1     4     0 ...     0     0     0]
#  [    1   179     0 ...     0     0     0]
#  [    1     4     0 ...     0     0     0]]

# %%
word2idx = tokenizer.word_index
idx2word = {value: key for key, value in word2idx.items()}

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import GRU, Dense, Input, Embedding, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import SparseCategoricalCrossentropy
